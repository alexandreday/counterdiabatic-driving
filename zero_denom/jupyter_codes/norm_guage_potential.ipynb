# %%
from quspin.operators import hamiltonian # Hamiltonians and operators
from quspin.basis import spin_basis_1d # Hilbert space spin basis
import numpy as np # generic math functions
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Sanity check for QuSpin: Guage potential
# $H=\sigma_z + \lambda \sigma_x$ . $A_{\lambda}= \sigma_y/4$

# %%
L=1 # system size

basis = spin_basis_1d(L)
hz=2.0
hx=1.0
hz_arr = [[hz,i] for i in range(L)] # OBC
hx_arr = [[hx,i] for i in range(L)] # OBC
# static and dynamic lists
static = [["z",hz_arr], ["x",hx_arr] ]
dynamic =[]
H = hamiltonian(static,dynamic,basis=basis,dtype=np.complex_)


# \partial lambda H
hx_lamb=1.0
hx_lamb_arr = [[hx_lamb,i] for i in range(L)] # OBC
static_lamb = [["x",hx_lamb_arr]]
dynamic_lamb =[]
op_lamb=hamiltonian(static_lamb,dynamic_lamb,basis=basis,dtype=np.complex_)
# Out:
# Hermiticity check passed!
# Symmetry checks passed!
# Hermiticity check passed!
# Symmetry checks passed!

# %%
E,V= H.eigh()
wij = (np.outer(E,np.ones(2**L))-np.outer(np.ones(2**L),E))
num_lamb = np.dot(V,np.dot(op_lamb.toarray(),np.conj(V)))
wij=wij+np.identity(2)
A_lamb = -1j*num_lamb/wij

# %%
np.fill_diagonal(A_lamb, 0.0)
print A_lamb
# Out:
# [[ 0.+0.j  -0.-0.2j]
#  [ 0.+0.2j  0.+0.j ]]

# %% [markdown]
# I have seen that I get the correct result for single body operator. Now I can compute results for many body systems. I want two figures how norm of gauge potential scales with L and how approximate guage potential scales with system size.

# %% [markdown]
# ### Better format of above code for single body hamiltonian

# %%
from quspin.operators import hamiltonian # Hamiltonians and operators
from quspin.basis import spin_basis_1d # Hilbert space spin basis
import numpy as np # generic math functions
import matplotlib.pyplot as plt



L=1
def Ham(L):
    basis = spin_basis_1d(L)
    hz=1.0
    hx=1.0
    hz_arr = [[hz,i] for i in range(L)] # OBC
    hx_arr = [[hx,i] for i in range(L)] # OBC
    # static and dynamic lists
    static = [["z",hz_arr], ["x",hx_arr] ]
    dynamic =[]
    H = hamiltonian(static,dynamic,basis=basis,dtype=np.complex_)
    return H


def del_lambda_Ham_single(L):
    basis = spin_basis_1d(L)
    hx_lamb=1.0
    hx_lamb_arr = [[hx_lamb,i] for i in range(L)] # OBC
    static_lamb = [["z",hx_lamb_arr]]
    dynamic_lamb =[]
    op_lamb=hamiltonian(static_lamb,dynamic_lamb,basis=basis,dtype=np.complex_)
    return op_lamb

def guage_potent_single(L):
    H=Ham(L)
    E,V= H.eigh()
    op_lamb= del_lambda_Ham(L)
    
    wij = (np.outer(E,np.ones(2**L))-np.outer(np.ones(2**L),E))
    num_lamb = np.dot(V,np.dot(op_lamb.toarray(),np.conj(V)))
    wij=wij+np.identity(2)
    A_lamb = -1j*num_lamb/wij
    np.fill_diagonal(A_lamb, 0.0)
    return A_lamb

def norm_single(A_lamb):    
    return np.linalg.norm(A_lamb, 'fro')

# %%
#print  guage_potent(1)
#print norm(guage_potent(1))
print del_lambda_Ham(2)
# Out:
# Hermiticity check passed!
# Symmetry checks passed!
# static mat:
#   (0, 1)	(1+0j)
#   (0, 2)	(1+0j)
#   (1, 0)	(1+0j)
#   (1, 3)	(1+0j)
#   (2, 0)	(1+0j)
#   (2, 3)	(1+0j)
#   (3, 1)	(1+0j)
#   (3, 2)	(1+0j)
#
#
# dynamic:

# %% [markdown]
# ### Many body hamiltonian: non -integrable and integrable cases
# $H=J \sum \sigma_{i}^x \sigma_{i+1}^x+ h_x \sum \sigma_i^x + h_z \sum \sigma_i^z$ where $\partial_{\lambda}H= \sigma_x$

# %%
from quspin.operators import hamiltonian # Hamiltonians and operators
from quspin.basis import spin_basis_1d # Hilbert space spin basis
import numpy as np # generic math functions
import matplotlib.pyplot as plt


def Ham_nonint(L):
    basis = spin_basis_1d(L)
    hz=(np.sqrt(5)+1)/4 #parameters used by Kim and Huse
    hx=(np.sqrt(5)+5)/8
    J=1.0
    hz_arr = [[hz,i] for i in range(L)] # OBC
    hx_arr = [[hx,i] for i in range(L)] # OBC
    J_arr = [[J,i,(i+1)%L] for i in range(L)] # PBC
    
    # static and dynamic lists
    static = [["xx",J_arr],["z",hz_arr], ["x",hx_arr] ]
    dynamic =[]
    H = hamiltonian(static,dynamic,basis=basis,dtype=np.complex_,check_symm=False,check_herm=False)
    return H

def Ham_int(L):
    basis = spin_basis_1d(L)
    hz=-0.5#(np.sqrt(5)+1)/4 #parameters used by Kim and Huse
    hx=0.0#(np.sqrt(5)+5)/8
    J=1.0
    hz_arr = [[hz,i] for i in range(L)] # OBC
    hx_arr = [[hx,i] for i in range(L)] # OBC
    J_arr = [[J,i,(i+1)%L] for i in range(L)] # PBC
    
    # static and dynamic lists
    static = [["xx",J_arr],["z",hz_arr], ["x",hx_arr] ]
    dynamic =[]
    H = hamiltonian(static,dynamic,basis=basis,dtype=np.complex_,check_symm=False,check_herm=False)
    return H

def del_lambda_Ham(L):
    basis = spin_basis_1d(L)
    hx_lamb=1.0
    hx_lamb_arr = [[hx_lamb,i] for i in range(L)] # OBC
    static_lamb = [["z",hx_lamb_arr]]
    dynamic_lamb =[]
    op_lamb=hamiltonian(static_lamb,dynamic_lamb,basis=basis,dtype=np.complex_,check_symm=False,check_herm=False)
    return op_lamb

def guage_potent(L):
    H=Ham_nonint(L)
    E,V= H.eigh()
    op_lamb= del_lambda_Ham(L)
    
    wij = (np.outer(E,np.ones(2**L))-np.outer(np.ones(2**L),E))
    num_lamb = np.dot(V,np.dot(op_lamb.toarray(),np.conj(V)))
    wij=wij+np.identity(2**L)
    A_lamb = -1j*num_lamb/wij
    np.fill_diagonal(A_lamb, 0.0)
    return A_lamb

def norm(A_lamb):    
    return np.linalg.norm(A_lamb, 'fro')

# %% [markdown]
# Somehow for odd powers, I am getting degenerate eigenvalues. Need to think about it more.

# %%
for i in range(2,8):
    L=i
    A_lamb=guage_potent(L)
    print L,norm(A_lamb)
# Out:
# 2 1.16310406783
# 3 3.69749211332e+15
# 4 1.96909753875e+14
# 5 nan
# /home/mohit/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:39: RuntimeWarning: divide by zero encountered in divide
# /home/mohit/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:39: RuntimeWarning: invalid value encountered in divide
# 6 6.86395540837e+14
# 7 nan

# %%
x=Ham_nonint(3).toarray()
E,V=np.linalg.eigh(x)
#print len(E)
#print E*np.identity(len(E))
#x_r=np.real(x)
#x_im=np.imag(x)
plt.imshow(E*np.identity(len(E)))
#plt.imshow(x_im)
plt.colorbar()

# %%
x=del_lambda_Ham(7).toarray()
x_r=np.real(x)
x_im=np.imag(x)
plt.imshow(x_r)
#plt.imshow(x_im)
plt.colorbar()

# %% [markdown]
# ### Removing degenerate subspace from guage potential
# + First, I need to check $\langle m (\lambda)|\partial_{\lambda}H | n (\lambda) \rangle =0$ for $n\neq m$ and when they are degenerate. If this is true, then matrix element corresponding to this $n,m$ should be zero, and hence, doesn't contribute to norm of guage potential.
# + This python trick might be useful https://stackoverflow.com/questions/11953867/how-do-i-find-out-eigenvectors-corresponding-to-a-particular-eigenvalue-of-a-mat

# %%
L=5
A_lamb=guage_potent(L)
print L,norm(A_lamb)
# Out:
# 5 nan
# /home/mohit/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:39: RuntimeWarning: divide by zero encountered in divide
# /home/mohit/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:39: RuntimeWarning: invalid value encountered in divide

# %%
H=Ham_nonint(L)
E,V= H.eigh()
print E
# Out:
# [-5.64305376 -4.97445235 -4.97445235 -4.04462557 -4.04462557 -2.75392588
#  -2.75392588 -2.46472336 -2.2161175  -2.2161175  -1.70923464 -1.50164884
#  -1.50164884 -0.85012203 -0.85012203 -0.05509412  0.24675298  0.24675298
#   0.63352059  0.63352059  1.57802813  1.84893934  1.84893934  1.95926222
#   1.95926222  2.76327452  3.55823195  3.55823195  4.09418509  4.09418509
#   4.43630438  9.09449885]

# %%
from collections import Counter
[item for item, count in Counter(E).iteritems() if count > 1]
# Out:
# [-2.7539258790635386]

# %%
x=[1,2,2,3,4,5,6,4]
from collections import Counter
[item for item, count in Counter(x).iteritems() if count > 1]
# Out:
# [2, 4]

# %% [markdown]
# ### Approximate gauge potential
# We don't have problem of degenerate states here when we include $\mu$.
# + Our gauge potential is given by: $  A_{\lambda}^{nm}= -i \hbar \dfrac{\partial_{\lambda}H^{nm}}{\omega_{nm}^2 + \mu^2} \omega_{nm}$
# + For non-zero $\mu$, gauge potential is an approximate one.

# %%
def guage_potent_mu(Ham,L, mu):
    E,V= Ham.eigh()
    op_lamb= del_lambda_Ham(L)
    wij = (np.outer(E,np.ones(2**L))-np.outer(np.ones(2**L),E))
    num_lamb = np.dot(V,np.dot(op_lamb.toarray(),np.conj(V)))
    #wij=wij+np.identity(2**L)
    A_lamb = -1j*num_lamb*wij/(wij**2+ mu**2)
    #np.fill_diagonal(A_lamb, 0.0)
    return A_lamb

H=Ham(1)
guage_potent_mu(H,1,1e-6)
# Out:
# Hermiticity check passed!
# Symmetry checks passed!
# array([[ 0.+0.j  , -0.-0.25j],
#        [ 0.+0.25j,  0.+0.j  ]])

# %%
# Out:
# Hermiticity check passed!
# Symmetry checks passed!

# %%
# Out:
# array([[ 0.+0.j  , -0.-0.25j],
#        [ 0.+0.25j,  0.+0.j  ]])

# %%
mu=1e-6
Ntot=11
length=np.zeros(Ntot-2)
norm_arr_nonint=np.zeros(Ntot-2)
for i in range(2,Ntot):
    L=i
    length[i-2]=i
    H=Ham_nonint(L)
    A_lamb=guage_potent_mu(H,L,mu)
    norm_arr_nonint[i-2]=norm(A_lamb)
    print length[i-2],norm_arr[i-2]
# Out:
# 2.0 1.02192370718
# 3.0 4.94267425086
# 4.0 6.52375541161
# 5.0 36.4550729628
# 6.0 164.798815533
# 7.0 657.881797634
# 8.0 585.140568179
# 9.0 8898.0353846
# 10.0 14431.1064725

# %%
mu=1e-15
Ntot=11
length=np.zeros(Ntot-2)
norm_arr_nonint_mu_smaller=np.zeros(Ntot-2)
for i in range(2,Ntot):
    L=i
    length[i-2]=i
    H=Ham_nonint(L)
    A_lamb=guage_potent_mu(H,L,mu)
    norm_arr_nonint_mu_smaller[i-2]=norm(A_lamb)
    print length[i-2],norm_arr_nonint_mu_smaller[i-2]
# Out:
# 2.0 0.968042231259
# 3.0 1.83107351675e+14
# 4.0 4.43704935767e+14
# 5.0 8.13996839753e+14
# 6.0 4.52131318375e+14
# 7.0 8.29651394702e+14
# 8.0 7.5370229319e+14
# 9.0 7.89893681322e+14
# 10.0 9.83698392167e+14

# %%
mu=1e-15
Ntot=11
length=np.zeros(Ntot-2)
norm_arr_int_mu_smaller=np.zeros(Ntot-2)
for i in range(2,Ntot):
    L=i
    length[i-2]=i
    H=Ham_int(L)
    A_lamb=guage_potent_mu(H,L,mu)
    norm_arr_int_mu_smaller[i-2]=norm(A_lamb)
    print length[i-2],norm_arr_int_mu_smaller[i-2]
# Out:
# 2.0 0.565685424949
# 3.0 2.13916607307e+14
# 4.0 1.31839311797e+14
# 5.0 5.40766655151e+14
# 6.0 7.27633308695e+14
# 7.0 1.09189692681e+15
# 8.0 1.17320017072e+15
# 9.0 1.37002031195e+15
# 10.0 1.75453753814e+15

# %%
mu=2e-15
Ntot=11
length=np.zeros(Ntot-2)
norm_arr_int_mu_smaller=np.zeros(Ntot-2)
for i in range(2,Ntot):
    L=i
    length[i-2]=i
    H=Ham_int(L)
    A_lamb=guage_potent_mu(H,L,mu)
    norm_arr_int_mu_smaller[i-2]=norm(A_lamb)

print length[i-2],norm_arr_int_mu_smaller[i-2]
# Out:
# 2.0 8.48528137424
# 3.0 1.17051882698e+14
# 4.0 3.12343158173e+14
# 5.0 3.66891722049e+14
# 6.0 5.56710982662e+14
# 7.0 6.91682628437e+14
# 8.0 7.88410126267e+14
# 9.0 9.73772512336e+14
# 10.0 1.31625430338e+15

# %%
#print len(norm_arr), len(length)
plt.semilogy(length,norm_arr_nonint_mu_smaller/np.sqrt(2**length), 'b.-')
plt.semilogy(length,norm_arr_int_mu_smaller/np.sqrt(2**length), 'r.-')
#plt.plot(length, np.exp(length), 'r.-')
#plt.grid()

# %% [markdown]
# ### Difference between integrable and non-integrable systems seen through degeneracy

# %%
H=Ham_int(L)
E,V= H.eigh()
wij = (np.outer(E,np.ones(2**L))-np.outer(np.ones(2**L),E))
print np.min(np.abs(wij+ np.identity(2**L))), L
a=wij+ np.identity(2**L)
x= np.sort(abs(a), axis=None)
# Out:
# 0.0 10

# %%
H=Ham_nonint(L)
E_nonint,V= H.eigh()
wij_nonint = (np.outer(E,np.ones(2**L))-np.outer(np.ones(2**L),E))
print np.min(np.abs(wij+ np.identity(2**L))), L
a_nonint=wij_nonint+ np.identity(2**L)
x_nonint= np.sort(abs(a_nonint), axis=None)
# Out:
# 0.0 10

# %%
x_in=np.arange(0,len(x))
plt.plot(x_in, x, 'b.-', label='Int')
plt.plot(x_in, x_nonint, 'r.-', label='Non-int')
plt.title('Number of degenerate energy levels')
plt.legend()

# %% [markdown]
# Better way of doing it will be to see level spacing. Integrable system should give a lot of level attraction while non-integrable systems should show a level repulsion.

# %% [markdown]
# ### $\mu$ scaling

# %%
muTot=10
mu_arr=np.logspace(-4,1.0,muTot)

# %%
L=10
norm_arr=np.zeros(muTot)
H=Ham_nonint(L)
for i in range(muTot):
    mu=mu_arr[i]
    A_lamb=guage_potent_mu(H,L,mu)
    norm_arr[i]=norm(A_lamb)
    print norm_arr[i], mu_arr[i]
# Out:
# 2453.64834386 0.0001
# 1478.01286375 0.00035938136638
# 835.476857961 0.00129154966501
# 434.373312487 0.00464158883361
# 220.705554471 0.016681005372
# 115.633848737 0.0599484250319
# 60.1259822305 0.215443469003
# 29.9342369033 0.774263682681
# 13.0272091499 2.78255940221
# 3.83587172162 10.0

# %%
muTot=10
mu_arr=np.logspace(-4,1.0,muTot)
L=10
norm_arr_int=np.zeros(muTot)
H=Ham_int(L)
for i in range(muTot):
    mu=mu_arr[i]
    A_lamb=guage_potent_mu(H,L,mu)
    norm_arr_int[i]=norm(A_lamb)
    print norm_arr_int[i], mu_arr[i]
# Out:
# 1755.76535725 0.0001
# 1596.62286395 0.00035938136638
# 1159.27125523 0.00129154966501
# 641.389118887 0.00464158883361
# 226.057896793 0.016681005372
# 119.087273718 0.0599484250319
# 67.5934408691 0.215443469003
# 33.7632128932 0.774263682681
# 13.9295543404 2.78255940221
# 3.53721127458 10.0

# %%
plt.loglog(mu_arr,norm_arr, 'b.-', label='Non-int')
plt.loglog(mu_arr,norm_arr_int, 'r.-', label='Int')
plt.xlabel(r"$\mu$")
plt.ylabel(r"$||A||$")
#plt.plot(length, np.exp(0.5*length), 'r.-')
plt.grid()
plt.title("L=10")
plt.legend()

# %% [markdown]
# ### Difference $\partial_{\lambda} H$ of integrable and non-integrable
# We expect the matrix of integrable systems to have more zeros because of selection rules.

# %%
H=Ham_int(10)
E,V= H.eigh()
op_lamb= del_lambda_Ham(L)
num_lamb = np.dot(V,np.dot(op_lamb.toarray(),np.conj(V)))

# %%
x=num_lamb
x_r=np.real(x)
x_im=np.imag(x)


#plt.subplot(1, 2, 1)
plt.imshow(x_r)
plt.colorbar()

#plt.subplot(1, 2, 2)
#plt.imshow(x_im)
#plt.colorbar()

#plt.tight_layout(pad=1.08)

# %%
H=Ham_nonint(10)
E,V= H.eigh()
op_lamb= del_lambda_Ham(L)
num_lamb = np.dot(V,np.dot(op_lamb.toarray(),np.conj(V)))

# %%
x=num_lamb
x_r=np.real(x)
x_im=np.imag(x)


#plt.subplot(1, 2, 1)
plt.imshow(x_r)
plt.colorbar()

#plt.subplot(1, 2, 2)
#plt.imshow(x_im)
#plt.colorbar()

#plt.tight_layout()

# %% [markdown]
# No difference! :(

# %% [markdown]
# ### Difference between gauge potential of integrable and non-integrable

# %%
mu=1e-6
L=10
H=Ham_int(L)
A_lamb_int=guage_potent_mu(H,L,mu)

# %%
x=A_lamb_int
x_r=np.real(x)
x_im=np.imag(x)


#plt.subplot(1, 2, 1)
plt.imshow(x_r)
plt.colorbar()

# %%
mu=1e-6
L=10
H=Ham_nonint(L)
A_lamb_nonint=guage_potent_mu(H,L,mu)

# %%
x=A_lamb_nonint
x_r=np.real(x)
x_im=np.imag(x)


#plt.subplot(1, 2, 1)
plt.imshow(x_r)
plt.colorbar()

# %%
norm(A_lamb_int), norm(A_lamb_nonint)
# Out:
# (9122.5674813516544, 14431.106472512662)
